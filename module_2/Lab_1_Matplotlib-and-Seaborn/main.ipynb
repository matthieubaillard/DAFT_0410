# %% [markdown]
# In progress: Challenge 1/3 ok, 2-3 to be done

# %% [markdown]
# # Module 1 - Lab 1 | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
fig, ax = plt.subplots(figsize=(8,4))
plt.plot(x,y, 'b', label  ='y')
plt.plot(x,z, 'g', ls = ':', label = 'z')
plt.legend()
plt.show()

#linestyle = ls = {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}

# %%
fig, ax = plt.subplots(figsize=(15,5))
plt.plot(y,x, 'b', label='y')
plt.plot(z,x, 'g', label = 'z')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,5))
    
plt.bar(x, y, color='red', label = 'Y')
plt.bar(x, z, color='orange', alpha = 0.5, label = 'Z')
  
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

ax1.plot(x,y)

ax2.plot(x,z)

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,5))

ax1.set_xlabel("X")
ax1.set_ylabel("Y")
ax1.plot(x,y)

ax2.set(xlabel="X", ylabel="Z")
ax2.plot(x,z)

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
x = np.arange(0,100)
y = x**2
z = np.exp(x)


fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,5))

ax1.set(title='Linear scale', xlabel="X", ylabel="Y")
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.plot(x,y)
ax1.plot(x,z)

ax2.set(title='Logarithmic scale', xlabel="X", ylabel="Y")
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.plot(x,y)
ax2.plot(x,z)

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
x = np.arange(0,100)
y = x**2
z = np.exp(x)


fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,5))

ax1.set(title='Linear scale', xlabel="X", ylabel="Y")
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.plot(x,y, label='y = x²')
ax1.plot(x,z, label='y = exp(x)')

ax2.set(title='Logarithmic scale', xlabel="X", ylabel="Y")
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.plot(x,y, label='y = x²')
ax2.plot(x,z, label='y = exp(x)')

plt.legend()
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('Fitbit2.csv', sep=',', encoding="utf8")
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
steps_month_df = fitbit[['Months_encoded', 'Steps']].groupby('Months_encoded').median()
print(steps_month_df)

# MEDIAN STEPS BY WORK_OR_WEEKEND
steps_week_df = fitbit[['Work_or_Weekend', 'Steps']].groupby('Work_or_Weekend').median()
print(steps_week_df,'0 = weekend; 1 = week day')

# MEDIAN STEPS BY MONTH / WEEK DAb
steps_month_weekend_df = fitbit[['Months_encoded', 'Work_or_Weekend', 'Steps']].groupby(['Months_encoded', 'Work_or_Weekend']).median()
steps_month_weekend_df

#steps_month_weekdays_df = fitbit[['Months_encoded', 'Work_or_Weekend', 'Steps']].groupby(['Months_encoded', 'Work_or_Weekend']).mean()
#steps_month_week_df

# Groupby multiple columns and aggregate()
#result = df.groupby(['Courses','Fee'])['Duration'].aggregate('count')
#print(result)

# MEDIAN STEPS BY MONTH / WEEK END
# Out:
#                   Steps
# Months_encoded
# 1               10366.0
# 2                9235.0
# 3               11122.0
# 4               13846.5
# 5               11998.0
# 6               12935.5
# 7               10644.0
# 8               12213.0
# 9                9343.0
# 10               7865.0
# 11               9453.5
# 12               8531.0
#                    Steps
# Work_or_Weekend
# 0                 9998.0
# 1                10445.5 0 = weekend; 1 = week day
#                                   Steps
# Months_encoded Work_or_Weekend
# 1              0                 9688.0
#                1                10707.0
# 2              0                11974.5
#                1                 8403.0
# 3              0                 3885.0
#                1                14068.0
# 4              0                 8682.0
#                1                17232.0
# 5              0                16095.0
#                1                 6756.0
# ...

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

ax1.set(title="Median Steps by Month", xlabel="Month", ylabel="Steps")
x = fitbit['Months_encoded'] #why isn't it working when replacing with steps_month_df ???
y = fitbit['Steps'] #why isn't it working when replacing with steps_month_df ???
ax1.plt.bar(x,y)

ax2.set(title="Median Steps by Week Days / WE", xlabel="Month", ylabel="Steps")
days =
steps = steps_week_df
ax2.plt.bar(days,steps)

plt.show((title="Median Steps by Week Days vs WE", xlabel="Month", ylabel="Steps"))


#fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,5))

#ax1.set(title='Linear scale', xlabel="X", ylabel="Y")
#ax1.set_xlabel('X')
#ax1.set_ylabel('Y')
#ax1.plot(x,y, label='y = x²')
#ax1.plot(x,z, label='y = exp(x)')

#ax2.set(title='Logarithmic scale', xlabel="X", ylabel="Y")
#ax2.set_xscale('log')
#ax2.set_yscale('log')
#ax2.plot(x,y, label='y = x²')
#ax2.plot(x,z, label='y = exp(x)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xd/d3dyqcnj5nq2br9rb4b8gqx80000gn/T/ipykernel_30582/4283686723.py in <module>
#       5 x = fitbit['Months_encoded'] #why isn't it working when replacing with steps_month_df ???
#       6 y = fitbit['Steps'] #why isn't it working when replacing with steps_month_df ???
# ----> 7 ax1.plt.bar(x,y)
#       8 plt.show()
#       9
#
# AttributeError: 'AxesSubplot' object has no attribute 'plt'

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

# %%
# CATEGORICAL VARIABLES
# your code here

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

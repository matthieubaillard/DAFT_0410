# %% [markdown]
# # Lab 15 - StackAPI
#
# #### Import the necessary libraries here:

# %%
NOTE APR 22: STILL HAVE AN ISSUE FINDING THE CONTENT OF THE ANSWERS IN THE API! :-(

# %%
#pip install stackapi
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
from datetime import datetime

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
from datetime import datetime

#this lists last month questions from the database:
questions = SITE.fetch('questions', min=datetime(2023, 3, 1), max=datetime(2023, 3, 31)) # OR using original Timstamp format: fromdate=1677625200, todate=1681901013

#now I want to return only the actual question (i.e. 'title' in the json data):
questions['items'][0]['title'] #this returns the 1st question! :-)

#now to iterate through the list of dictionaries in the "items" key:
for item in questions["items"]:
    # access the value of the "title" key in each nested dictionary
    print(item["title"])
# Out:
# {'backoff': 0, 'has_more': True, 'page': 5, 'quota_max': 300, 'quota_remaining': 254, 'total': 0, 'items': [{'tags': ['git', 'gerrit'], 'owner': {'reputation': 308, 'user_id': 10647190, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/photo.jpg?sz=256', 'display_name': 'Louay GOURRIDA', 'link': 'https://stackoverflow.com/users/10647190/louay-gourrida'}, 'is_answered': True, 'view_count': 38, 'accepted_answer_id': 75887770, 'answer_count': 1, 'score': 1, 'last_activity_date': 1680220799, 'creation_date': 1680175742, 'question_id': 75887648, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/75887648/how-to-push-in-gerrit-without-creating-new-commit', 'title': 'How to push in Gerrit without creating new commit'}, {'tags': ['mysql', 'phpmyadmin'], 'owner': {'reputation': 91, 'user_id': 10231558, 'user_type': 'registered', 'profile_image': 'https://i.stack.imgur.com/OFbxs.jpg?s=256
# ...

# %%
#Just to helop understand the json structure and what we are actually trying to access

#questions = {'key1':value,
#             'key2':value,
#             'key3':value,
#             'key4':value,
#             'key5':value,
#             'key6':value
#             'items': [{'tags': ['tag1','tag2','tag3'],
#                        'another_key':value,
#                        'another_key':value,
#                        'another_key':value,
#                        'another_key':value,
#                        'title':'Here are the actual questions I would like to scrape and list!'},
#                       {'tags': ['tag1','tag2','tag3'],
#                        'another_key':value,
#                        'another_key':value,
#                        'another_key':value,
#                        'another_key':value,
#                        'title':'Here is another questions I would like to scrape and list!'}
#                       {'tags': ['tag1','tag2','tag3'],
#                        'another_key':value,
#                        'another_key':value,
#                        'another_key':value,
#                        'another_key':value,
#                        'title':'Here is another questions I would like to scrape and list!'}]}
#

# %%
answers = SITE.fetch('answers', fromdate=1677625200, todate=1681901013)
#len(answers['items']) returns 500 answers
#print(answers['items'][0]) # returns the 1st item in answers
print(answers)

# BUT I CANNOT FIND THE ANSWERS BODY HERE, SO OBVIOUSLY THE FOLLOWING WILL NOT RETURN ANYTHINHG EITHER :-(

#answers_list = []
#answers['items'][0]['body']
#for item in answers['items']:
#    answers_list.append(item['body'])
#print(answers_list[0])
# Out:
# {'backoff': 0, 'has_more': True, 'page': 5, 'quota_max': 300, 'quota_remaining': 264, 'total': 0, 'items': [{'owner': {'reputation': 214, 'user_id': 21214111, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/77fcb89cf68dcbb04e169fce4830dbac?s=256&d=identicon&r=PG', 'display_name': 'smashapalooza', 'link': 'https://stackoverflow.com/users/21214111/smashapalooza'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1682177076, 'last_edit_date': 1682177076, 'creation_date': 1681343845, 'answer_id': 76000670, 'question_id': 75998506, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'reputation': 1, 'user_id': 21639384, 'user_type': 'unregistered', 'profile_image': 'https://www.gravatar.com/avatar/d3c06f484670059807a29629eddd9a92?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'K A Narayanankutty', 'link': 'https://stackoverflow.com/users/21639384/k-a-narayanankutty'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1682176955, 'last_edit_d
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
questions_python = SITE.fetch('questions', fromdate=1680300000, todate=1681901013, 
    min=5, tagged='python', sort='votes', order='desc')

# Check number of results
# print(len(questions_python['items']))
# today 1681926241 returned no result, so we have changed fromdate to April 1st, which returns 15 results

#to print this month questions
#for item in questions_python["items"]:
#    print(item["title"])
    
#print only the question with most votes:
print("This month Python question with most votes: ", questions_python["items"][0]["title"])
# Out:
# This month Python question with most votes:  Can you explain this difference of recursion depth in Python using these seemingly equivalent functions?

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
questions2 = SITE.fetch('questions', answer_id=[6784, 6473])
print(questions2)

#THIS DOES NOT WORK :-(
# Out:
# {'backoff': 0, 'has_more': True, 'page': 5, 'quota_max': 300, 'quota_remaining': 224, 'total': 0, 'items': [{'tags': ['spring', 'spring-boot', 'caching', 'spring-webflux', 'project-reactor'], 'owner': {'reputation': 605, 'user_id': 993822, 'user_type': 'registered', 'accept_rate': 50, 'profile_image': 'https://www.gravatar.com/avatar/40b4b8762e383038349439b7d6a5f857?s=256&d=identicon&r=PG', 'display_name': 'stumbler', 'link': 'https://stackoverflow.com/users/993822/stumbler'}, 'is_answered': True, 'view_count': 5524, 'accepted_answer_id': 71533892, 'answer_count': 2, 'score': 7, 'last_activity_date': 1682182060, 'creation_date': 1647632283, 'last_edit_date': 1679762705, 'question_id': 71532361, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/71532361/spring-boot-reactive-caching', 'title': 'Spring boot Reactive caching'}, {'tags': ['excel', 'excel-formula'], 'owner': {'reputation': 123, 'user_id': 2094936, 'user_type': 'registered', 'profile_image': 'h
# ...
